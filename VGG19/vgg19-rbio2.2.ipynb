# %% [markdown]
# # A Study on Arrhythmia via ECG Signal Classification Using the Convolutional Neural Network
#
# Yomna Hesham Amin Fekry  *(G19093453)*
#
# Ahmed Mohamed Farouk  *(2000630)*

# %% [markdown]
# This is an implementation to the paper **"A Study on Arrhythmia via ECG Signal Classification Using the Convolutional Neural Network"**.
#
# The author of the paper said that the proposed algorithm is implemented in Matlab, but we cannot find this implementation, so we implemented it in Python

# %% [markdown]
# # Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import csv
import itertools
import collections

import pywt

from scipy import stats

from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Conv1D, AvgPool1D, Flatten, Dense, Dropout, Softmax
from keras.optimizers import Adam
#from keras.utils.np_utils import to_categorical
from tensorflow.keras.utils import to_categorical
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model
from keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report

# %matplotlib inline

# %% [markdown]
# # matplotlib Settings

# %%
plt.rcParams["figure.figsize"] = (30,6)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Methods Definitions

# %%
def denoise(data):
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))

    datarec = pywt.waverec(coeffs, 'sym4')

    return datarec

# %% [markdown]
# # Variables Definitions

# %%
path = '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# %%
count_classes
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# # Prepere Input Files

# %%
# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt
records = list()
annotations = list()
filenames.sort()

# %%
filenames
# Out:
# ['100.csv',
#  '100annotations.txt',
#  '101.csv',
#  '101annotations.txt',
#  '102.csv',
#  '102annotations.txt',
#  '103.csv',
#  '103annotations.txt',
#  '104.csv',
#  '104annotations.txt',
#  '105.csv',
#  '105annotations.txt',
#  '106.csv',
#  '106annotations.txt',
#  '107.csv',
#  '107annotations.txt',
#  '108.csv',
#  '108annotations.txt',
#  '109.csv',
#  '109annotations.txt',
#  '111.csv',
#  '111annotations.txt',
#  '112.csv',
#  '112annotations.txt',
#  '113.csv',
#  '113annotations.txt',
#  '114.csv',
#  '114annotations.txt',
#  '115.csv',
#  '115annotations.txt',
#  '116.csv',
#  '116annotations.txt',
#  '117.csv',
#  '117annotations.txt',
#  '118.csv',
#  '118annotations.txt',
#  '119.csv',
#  '119annotations.txt',
#  '121.csv',
#  '121annotations.txt',
#  '122.csv',
#  '122annotations.txt',
#  '123.csv',
#  '123annotations.txt',
#  '124.csv',
#  '124annotations.txt',
#  '200.csv',
#  '200annotations.txt',
#  '201.csv',
#  '201annotations.txt',
#  '202.csv',
#  '202annotations.txt',
#  '203.csv',
#  '203annotations.txt',
#  '205.csv',
#  '205annotations.txt',
#  '207.csv',
#  '207annotations.txt',
#  '208.csv',
#  '208annotations.txt',
#  '209.csv',
#  '209annotations.txt',
#  '210.csv',
#  '210annotations.txt',
#  '212.csv',
#  '212annotations.txt',
#  '213.csv',
#  '213annotations.txt',
#  '214.csv',
#  '214annotations.txt',
#  '215.csv',
#  '215annotations.txt',
#  '217.csv',
#  '217annotations.txt',
#  '219.csv',
#  '219annotations.txt',
#  '220.csv',
#  '220annotations.txt',
#  '221.csv',
#  '221annotations.txt',
#  '222.csv',
#  '222annotations.txt',
#  '223.csv',
#  '223annotations.txt',
#  '228.csv',
#  '228annotations.txt',
#  '230.csv',
#  '230annotations.txt',
#  '231.csv',
#  '231annotations.txt',
#  '232.csv',
#  '232annotations.txt',
#  '233.csv',
#  '233annotations.txt',
#  '234.csv',
#  '234annotations.txt']

# %%
# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)

    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
records
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/100.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/101.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/102.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/103.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/104.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/105.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/106.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/107.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/108.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/109.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/111.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/112.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/113.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/114.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/115.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/116.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/117.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/118.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/119.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/121.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/122.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/123.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/124.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/200.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/201.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/202.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/203.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/205.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/207.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/208.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/209.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/210.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/212.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/213.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/214.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/215.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/217.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/219.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/220.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/221.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/222.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/223.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/228.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/230.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/231.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/232.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/233.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/234.csv']

# %%
filename
# Out:
# '234annotations'

# %%
len(records)
# Out:
# 48

# %%
file_extension
# Out:
# '.txt'

# %%
annotations
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/100annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/101annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/102annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/103annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/104annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/105annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/106annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/107annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/108annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/109annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/111annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/112annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/113annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/114annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/115annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/116annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/117annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/118annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/119annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/121annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/122annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/123annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/124annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/200annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/201annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/202annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/203annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/205annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/207annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/208annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/209annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/210annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/212annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/213annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/214annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/215annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/217annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/219annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/220annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/221annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/222annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/223annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/228annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/230annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/231annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/232annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/233annotations.txt',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/234annotations.txt']

# %%
records
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/100.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/101.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/102.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/103.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/104.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/105.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/106.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/107.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/108.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/109.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/111.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/112.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/113.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/114.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/115.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/116.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/117.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/118.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/119.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/121.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/122.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/123.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/124.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/200.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/201.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/202.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/203.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/205.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/207.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/208.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/209.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/210.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/212.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/213.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/214.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/215.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/217.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/219.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/220.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/221.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/222.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/223.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/228.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/230.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/231.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/232.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/233.csv',
#  '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/234.csv']

# %% [markdown]
# # Data Extraction and Preprocessing

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/234.csv")
df
# Out:
#         'sample #'  'MLII'  'V1'
# 0                0    1008  1051
# 1                1    1008  1051
# 2                2    1008  1051
# 3                3    1008  1051
# 4                4    1008  1051
# ...            ...     ...   ...
# 649995      649995     946  1038
# 649996      649996     946  1038
# 649997      649997     945  1039
# 649998      649998     948  1040
# 649999      649999    1024  1024
#
# [650000 rows x 3 columns]

# %%
txt= open('/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/234annotations.txt',mode="r")
print(txt)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/234annotations.txt' mode='r' encoding='UTF-8'>

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1

    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:700])
        plt.show()

    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()

    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines()
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat
                    if r is 1 and not example_beat_printed:
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:57: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:57: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-18-6f8c69895a3a>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# <ipython-input-18-6f8c69895a3a>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# <ipython-input-18-6f8c69895a3a>:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# <ipython-input-18-6f8c69895a3a>:57: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1 and not example_beat_printed:
# (100012, 360) (100012,)

# %%
type(X)
# Out:
# list

# %%
X
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
type(y)
# Out:
# list

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])
#         X[i].append(y[i])

print(np.shape(X))
# Out:
# (100012, 361)

# %% [markdown]
# # Classes Distribution

# %%
X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%',textprops={'fontsize': 20})
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %% [markdown]
# # Rebalancing Classes

# %%
df_1=X_train_df[X_train_df[X_train_df.shape[1]-1]==1]
df_2=X_train_df[X_train_df[X_train_df.shape[1]-1]==2]
df_3=X_train_df[X_train_df[X_train_df.shape[1]-1]==3]
df_4=X_train_df[X_train_df[X_train_df.shape[1]-1]==4]
# df_5=X_train_df[X_train_df[X_train_df.shape[1]-1]==5]
df_0=(X_train_df[X_train_df[X_train_df.shape[1]-1]==0]).sample(n=5000,random_state=42)

df_1_upsample=resample(df_1,replace=True,n_samples=5000,random_state=122)
df_2_upsample=resample(df_2,replace=True,n_samples=5000,random_state=123)
df_3_upsample=resample(df_3,replace=True,n_samples=5000,random_state=124)
df_4_upsample=resample(df_4,replace=True,n_samples=5000,random_state=125)
# df_5_upsample=resample(df_5,replace=True,n_samples=5000,random_state=126)

# X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample,df_5_upsample])
X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample])

# %%
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    5000
# 1.0    5000
# 2.0    5000
# 3.0    5000
# 4.0    5000
# Name: 360, dtype: int64

# %%
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle = plt.Circle( (0,0), 0.7, color='white')

# Sử dụng thêm tham số fontsize
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'], autopct='%1.1f%%', textprops={'fontsize': 20})
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    5000
# 1.0    5000
# 2.0    5000
# 3.0    5000
# 4.0    5000
# Name: 360, dtype: int64

# %% [markdown]
# # Train-Test Split

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))
# Out:
# X_train :  (20000, 361)
# X_test  :  (5000, 361)

# %%
target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))
# Out:
# (20000, 5) (5000, 5)

# %%
train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# (20000, 360, 1) (5000, 360, 1)

# %%
# Define a function to extract wavelet features from ECG signals
def extract_wavelet_features(ecg_signal):
    numeric_signal = ecg_signal.astype(float)
    coeffs = pywt.wavedec(numeric_signal, 'rbio2.2', level=4)
    features = []
    for i, c in enumerate(coeffs):
        features.extend([np.mean(c), np.std(c), np.max(c), np.min(c)])
    return pd.Series(features)

# Apply wavelet feature extraction function to each ECG signal
data_train_wavelet = [extract_wavelet_features(row) for row in train_x.reshape(len(train_x), -1)]
data_test_wavelet = [extract_wavelet_features(row) for row in test_x.reshape(len(test_x), -1)]

# Convert the lists to DataFrames
data_train_wavelet = pd.DataFrame(data_train_wavelet)
data_test_wavelet = pd.DataFrame(data_test_wavelet)

# Concatenate wavelet features with original features
train_x_wavelet = pd.concat([pd.DataFrame(train_x.reshape(len(train_x), -1)), data_train_wavelet], axis=1)
test_x_wavelet = pd.concat([pd.DataFrame(test_x.reshape(len(test_x), -1)), data_test_wavelet], axis=1)

# Separate features and labels for the wavelet features
X_train_wavelet = train_x_wavelet.values.reshape(len(train_x_wavelet), train_x_wavelet.shape[1], 1)
X_test_wavelet = test_x_wavelet.values.reshape(len(test_x_wavelet), test_x_wavelet.shape[1], 1)

# %% [markdown]
# ## Building the Model Architecture

# %%
#VGG19
from keras.models import Sequential
from keras.layers import Conv1D, AveragePooling1D, Flatten, Dense, Softmax, Dropout
from keras import regularizers

model2 = Sequential()

# Adding a Convolution Layer C1
model2.add(Conv1D(filters=16, kernel_size=13, padding='same', activation='relu', input_shape=(380, 1)))

# Adding an Average Pooling Layer S2
model2.add(AveragePooling1D(pool_size=3, strides=2))

# Adding a Convolution Layer C3
model2.add(Conv1D(filters=32, kernel_size=15, padding='same', activation='relu'))

# Adding an Average Pooling Layer S4
model2.add(AveragePooling1D(pool_size=3, strides=2))

# Adding a Convolution Layer C5
model2.add(Conv1D(filters=64, kernel_size=17, padding='same', activation='relu'))

# Adding an Average Pooling Layer S6
model2.add(AveragePooling1D(pool_size=3, strides=2))

# Adding a Convolution Layer C7
model2.add(Conv1D(filters=128, kernel_size=19, padding='same', activation='relu'))

# Adding an Average Pooling Layer S8
model2.add(AveragePooling1D(pool_size=3, strides=2))

# Flattening the layer
model2.add(Flatten())

# Dropout layer
model2.add(Dropout(0.5))

# Adding a Dense layer with regularization l2(0.0001)
model2.add(Dense(35, kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001), activation='relu'))

# Adding a Dense layer with regularization l2(0.0001)
model2.add(Dense(5, kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001), activation='softmax'))

# Display model summary
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 380, 16)           224
#
#  average_pooling1d (Average  (None, 189, 16)           0
#  Pooling1D)
#
#  conv1d_1 (Conv1D)           (None, 189, 32)           7712
#
#  average_pooling1d_1 (Avera  (None, 94, 32)            0
#  gePooling1D)
#
#  conv1d_2 (Conv1D)           (None, 94, 64)            34880
#
#  average_pooling1d_2 (Avera  (None, 46, 64)            0
#  gePooling1D)
#
#  conv1d_3 (Conv1D)           (None, 46, 128)           155776
#
#  average_pooling1d_3 (Avera  (None, 22, 128)           0
#  gePooling1D)
#
#  flatten (Flatten)           (None, 2816)              0
#
#  dropout (Dropout)           (None, 2816)              0
#
#  dense (Dense)               (None, 35)                98595
#
#  dense_1 (Dense)             (None, 5)                 180
#
# =================================================================
# Total params: 297367 (1.13 MB)
# Trainable params: 297367 (1.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compiling the model

# %%
model2.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# ## Fitting the model

# %%
history2 = model2.fit(X_train_wavelet, train_y, batch_size=36, epochs=60, verbose=1, validation_data=(X_test_wavelet, test_y))
# Out:
# Epoch 1/60
# 556/556 [==============================] - 12s 8ms/step - loss: 0.3635 - accuracy: 0.8734 - val_loss: 0.1255 - val_accuracy: 0.9606
# Epoch 2/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.1428 - accuracy: 0.9562 - val_loss: 0.0995 - val_accuracy: 0.9702
# Epoch 3/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.1129 - accuracy: 0.9668 - val_loss: 0.0907 - val_accuracy: 0.9744
# Epoch 4/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0915 - accuracy: 0.9741 - val_loss: 0.0903 - val_accuracy: 0.9758
# Epoch 5/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0871 - accuracy: 0.9751 - val_loss: 0.0834 - val_accuracy: 0.9798
# Epoch 6/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0754 - accuracy: 0.9795 - val_loss: 0.0907 - val_accuracy: 0.9802
# Epoch 7/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0722 - accuracy: 0.9821 - val_loss: 0.0678 - val_accuracy: 0.9832
# Epoch 8/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0639 - accuracy: 0.9844 - val_loss: 0.0832 - val_accuracy: 0.9810
# Epoch 9/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0599 - accuracy: 0.9862 - val_loss: 0.0714 - val_accuracy: 0.9844
# Epoch 10/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0616 - accuracy: 0.9854 - val_loss: 0.0748 - val_accuracy: 0.9848
# Epoch 11/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0590 - accuracy: 0.9873 - val_loss: 0.0677 - val_accuracy: 0.9874
# Epoch 12/60
# 556/556 [==============================] - 5s 9ms/step - loss: 0.0488 - accuracy: 0.9905 - val_loss: 0.0695 - val_accuracy: 0.9858
# Epoch 13/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.0545 - accuracy: 0.9892 - val_loss: 0.0663 - val_accuracy: 0.9892
# Epoch 14/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0498 - accuracy: 0.9905 - val_loss: 0.0640 - val_accuracy: 0.9904
# Epoch 15/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0507 - accuracy: 0.9910 - val_loss: 0.0671 - val_accuracy: 0.9894
# Epoch 16/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0526 - accuracy: 0.9904 - val_loss: 0.0631 - val_accuracy: 0.9902
# Epoch 17/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0439 - accuracy: 0.9926 - val_loss: 0.0649 - val_accuracy: 0.9906
# Epoch 18/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0441 - accuracy: 0.9926 - val_loss: 0.0711 - val_accuracy: 0.9874
# Epoch 19/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0414 - accuracy: 0.9926 - val_loss: 0.0650 - val_accuracy: 0.9892
# Epoch 20/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0437 - accuracy: 0.9931 - val_loss: 0.0661 - val_accuracy: 0.9908
# Epoch 21/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0406 - accuracy: 0.9932 - val_loss: 0.0632 - val_accuracy: 0.9908
# Epoch 22/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0403 - accuracy: 0.9934 - val_loss: 0.0600 - val_accuracy: 0.9908
# Epoch 23/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0429 - accuracy: 0.9934 - val_loss: 0.0657 - val_accuracy: 0.9912
# Epoch 24/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0392 - accuracy: 0.9936 - val_loss: 0.0619 - val_accuracy: 0.9914
# Epoch 25/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.0456 - accuracy: 0.9920 - val_loss: 0.0661 - val_accuracy: 0.9900
# Epoch 26/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.0354 - accuracy: 0.9948 - val_loss: 0.0585 - val_accuracy: 0.9898
# Epoch 27/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0353 - accuracy: 0.9943 - val_loss: 0.0593 - val_accuracy: 0.9918
# Epoch 28/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0382 - accuracy: 0.9945 - val_loss: 0.0637 - val_accuracy: 0.9904
# Epoch 29/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0350 - accuracy: 0.9951 - val_loss: 0.0607 - val_accuracy: 0.9908
# Epoch 30/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.0342 - accuracy: 0.9950 - val_loss: 0.0552 - val_accuracy: 0.9928
# Epoch 31/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0373 - accuracy: 0.9947 - val_loss: 0.0562 - val_accuracy: 0.9922
# Epoch 32/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0334 - accuracy: 0.9952 - val_loss: 0.0639 - val_accuracy: 0.9906
# Epoch 33/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0349 - accuracy: 0.9947 - val_loss: 0.0551 - val_accuracy: 0.9920
# Epoch 34/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0322 - accuracy: 0.9956 - val_loss: 0.0573 - val_accuracy: 0.9930
# Epoch 35/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0337 - accuracy: 0.9950 - val_loss: 0.0654 - val_accuracy: 0.9932
# Epoch 36/60
# 556/556 [==============================] - 7s 12ms/step - loss: 0.0308 - accuracy: 0.9958 - val_loss: 0.0625 - val_accuracy: 0.9910
# Epoch 37/60
# 556/556 [==============================] - 6s 11ms/step - loss: 0.0385 - accuracy: 0.9938 - val_loss: 0.0686 - val_accuracy: 0.9898
# Epoch 38/60
# 556/556 [==============================] - 6s 11ms/step - loss: 0.0290 - accuracy: 0.9962 - val_loss: 0.0626 - val_accuracy: 0.9918
# Epoch 39/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0274 - accuracy: 0.9969 - val_loss: 0.0884 - val_accuracy: 0.9872
# Epoch 40/60
# 556/556 [==============================] - 5s 10ms/step - loss: 0.0340 - accuracy: 0.9951 - val_loss: 0.0692 - val_accuracy: 0.9910
# Epoch 41/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0297 - accuracy: 0.9963 - val_loss: 0.0569 - val_accuracy: 0.9930
# Epoch 42/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0338 - accuracy: 0.9958 - val_loss: 0.0572 - val_accuracy: 0.9928
# Epoch 43/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0268 - accuracy: 0.9973 - val_loss: 0.0628 - val_accuracy: 0.9912
# Epoch 44/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0332 - accuracy: 0.9948 - val_loss: 0.0542 - val_accuracy: 0.9930
# Epoch 45/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0268 - accuracy: 0.9967 - val_loss: 0.0734 - val_accuracy: 0.9912
# Epoch 46/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0262 - accuracy: 0.9969 - val_loss: 0.0656 - val_accuracy: 0.9934
# Epoch 47/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.0301 - accuracy: 0.9954 - val_loss: 0.0660 - val_accuracy: 0.9926
# Epoch 48/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0274 - accuracy: 0.9966 - val_loss: 0.0599 - val_accuracy: 0.9920
# Epoch 49/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0276 - accuracy: 0.9969 - val_loss: 0.0597 - val_accuracy: 0.9908
# Epoch 50/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0253 - accuracy: 0.9969 - val_loss: 0.0627 - val_accuracy: 0.9926
# Epoch 51/60
# 556/556 [==============================] - 4s 6ms/step - loss: 0.0285 - accuracy: 0.9958 - val_loss: 0.0663 - val_accuracy: 0.9920
# Epoch 52/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0271 - accuracy: 0.9966 - val_loss: 0.0697 - val_accuracy: 0.9922
# Epoch 53/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0250 - accuracy: 0.9973 - val_loss: 0.0661 - val_accuracy: 0.9896
# Epoch 54/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0256 - accuracy: 0.9969 - val_loss: 0.0613 - val_accuracy: 0.9920
# Epoch 55/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0261 - accuracy: 0.9969 - val_loss: 0.0673 - val_accuracy: 0.9906
# Epoch 56/60
# 556/556 [==============================] - 3s 6ms/step - loss: 0.0277 - accuracy: 0.9959 - val_loss: 0.0545 - val_accuracy: 0.9920
# Epoch 57/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0280 - accuracy: 0.9962 - val_loss: 0.0598 - val_accuracy: 0.9918
# Epoch 58/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0266 - accuracy: 0.9969 - val_loss: 0.0669 - val_accuracy: 0.9936
# Epoch 59/60
# 556/556 [==============================] - 4s 7ms/step - loss: 0.0227 - accuracy: 0.9979 - val_loss: 0.0617 - val_accuracy: 0.9934
# Epoch 60/60
# 556/556 [==============================] - 4s 8ms/step - loss: 0.0251 - accuracy: 0.9968 - val_loss: 0.0655 - val_accuracy: 0.9888

# %% [markdown]
# **Plotting the loss convergence**

# %%
# summarize history for loss
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Plotting accuracy**

# %%
# summarize history for accuracy
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Finding the loss and accuracy of the model

# %%
score = model2.evaluate(X_test_wavelet, test_y)

print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0655 - accuracy: 0.9888
# Test Loss: 0.065492644906044
# Test accuracy: 0.9887999892234802

# %%
model2.save('/content/drive/MyDrive/Colab Notebooks/PPTK/VGG19/Parameters/VGG19_rbio2.2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Assuming you have predictions from your model
predictions = model2.predict(X_test_wavelet)

# Convert predictions to one-hot encoding
y_pred = np.argmax(predictions, axis=1)

# Convert true labels to one-hot encoding
y_true = np.argmax(test_y, axis=1)

# Calculate confusion matrix
conf_mat = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_mat)

# Calculate precision, recall, and F1 score
report = classification_report(y_true, y_pred, target_names=classes)
print("Classification Report:")
print(report)
# Out:
# 157/157 [==============================] - 0s 3ms/step
# Confusion Matrix:
# [[1024    1    1   11    6]
#  [   3  953    0    1    1]
#  [   1    0 1011    3    0]
#  [  10    0    1 1005    1]
#  [   8    1    0    7  951]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.98      0.98      0.98      1043
#            L       1.00      0.99      1.00       958
#            R       1.00      1.00      1.00      1015
#            A       0.98      0.99      0.98      1017
#            V       0.99      0.98      0.99       967
#
#     accuracy                           0.99      5000
#    macro avg       0.99      0.99      0.99      5000
# weighted avg       0.99      0.99      0.99      5000

# %%
# Plot non-normalized confusion matrix
def plot_confusion_matrix(cm, classes,normalize=False,cmap="YlGnBu"):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    acc = "{:.2f}".format(np.trace(conf_mat)/np.sum(conf_mat)*100)
    plt.title('Confusion matrix \n Classification accuracy is: ' + str(acc)+'%')
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plt.figure(figsize=(5, 5))
plot_confusion_matrix(conf_mat, classes=classes,normalize=False)
plt.show()
