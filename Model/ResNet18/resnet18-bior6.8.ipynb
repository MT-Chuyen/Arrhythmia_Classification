# %% [markdown]
# # A Study on Arrhythmia via ECG Signal Classification Using the Convolutional Neural Network
#
# Yomna Hesham Amin Fekry  *(G19093453)*
#
# Ahmed Mohamed Farouk  *(2000630)*

# %% [markdown]
# This is an implementation to the paper **"A Study on Arrhythmia via ECG Signal Classification Using the Convolutional Neural Network"**.
#
# The author of the paper said that the proposed algorithm is implemented in Matlab, but we cannot find this implementation, so we implemented it in Python

# %% [markdown]
# # Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import csv
import itertools
import collections

import pywt

from scipy import stats

from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Conv1D, AvgPool1D, Flatten, Dense, Dropout, Softmax
from keras.optimizers import Adam
#from keras.utils.np_utils import to_categorical
from tensorflow.keras.utils import to_categorical
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model
from keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report

# %matplotlib inline

# %% [markdown]
# # matplotlib Settings

# %%
plt.rcParams["figure.figsize"] = (30,6)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Methods Definitions

# %%
def denoise(data):
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))

    datarec = pywt.waverec(coeffs, 'sym4')

    return datarec

# %% [markdown]
# # Variables Definitions

# %%
path = '/content/drive/MyDrive/Colab Notebooks/PPTK/mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# %% [markdown]
# # Prepere Input Files

# %%
# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt
records = list()
annotations = list()
filenames.sort()

# %%
# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)

    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %% [markdown]
# # Data Extraction and Preprocessing

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1

    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:700])
        plt.show()

    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()

    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines()
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat
                    if r is 1 and not example_beat_printed:
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:57: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:57: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-8-6f8c69895a3a>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# <ipython-input-8-6f8c69895a3a>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# <ipython-input-8-6f8c69895a3a>:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# <ipython-input-8-6f8c69895a3a>:57: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1 and not example_beat_printed:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])
#         X[i].append(y[i])

print(np.shape(X))
# Out:
# (100012, 361)

# %% [markdown]
# # Classes Distribution

# %%
X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %% [markdown]
# # Rebalancing Classes

# %%
df_1=X_train_df[X_train_df[X_train_df.shape[1]-1]==1]
df_2=X_train_df[X_train_df[X_train_df.shape[1]-1]==2]
df_3=X_train_df[X_train_df[X_train_df.shape[1]-1]==3]
df_4=X_train_df[X_train_df[X_train_df.shape[1]-1]==4]
# df_5=X_train_df[X_train_df[X_train_df.shape[1]-1]==5]
df_0=(X_train_df[X_train_df[X_train_df.shape[1]-1]==0]).sample(n=5000,random_state=42)

df_1_upsample=resample(df_1,replace=True,n_samples=5000,random_state=122)
df_2_upsample=resample(df_2,replace=True,n_samples=5000,random_state=123)
df_3_upsample=resample(df_3,replace=True,n_samples=5000,random_state=124)
df_4_upsample=resample(df_4,replace=True,n_samples=5000,random_state=125)
# df_5_upsample=resample(df_5,replace=True,n_samples=5000,random_state=126)

# X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample,df_5_upsample])
X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample])

# %%
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    5000
# 1.0    5000
# 2.0    5000
# 3.0    5000
# 4.0    5000
# Name: 360, dtype: int64

# %% [markdown]
# # Train-Test Split

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))
# Out:
# X_train :  (20000, 361)
# X_test  :  (5000, 361)

# %%
target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))
# Out:
# (20000, 5) (5000, 5)

# %%
train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# (20000, 360, 1) (5000, 360, 1)

# %%
# Define a function to extract wavelet features from ECG signals
def extract_wavelet_features(ecg_signal):
    numeric_signal = ecg_signal.astype(float)
    coeffs = pywt.wavedec(numeric_signal, 'bior6.8', level=4)
    features = []
    for i, c in enumerate(coeffs):
        features.extend([np.mean(c), np.std(c), np.max(c), np.min(c)])
    return pd.Series(features)

# Apply wavelet feature extraction function to each ECG signal
data_train_wavelet = [extract_wavelet_features(row) for row in train_x.reshape(len(train_x), -1)]
data_test_wavelet = [extract_wavelet_features(row) for row in test_x.reshape(len(test_x), -1)]

# Convert the lists to DataFrames
data_train_wavelet = pd.DataFrame(data_train_wavelet)
data_test_wavelet = pd.DataFrame(data_test_wavelet)

# Concatenate wavelet features with original features
train_x_wavelet = pd.concat([pd.DataFrame(train_x.reshape(len(train_x), -1)), data_train_wavelet], axis=1)
test_x_wavelet = pd.concat([pd.DataFrame(test_x.reshape(len(test_x), -1)), data_test_wavelet], axis=1)

# Separate features and labels for the wavelet features
X_train_wavelet = train_x_wavelet.values.reshape(len(train_x_wavelet), train_x_wavelet.shape[1], 1)
X_test_wavelet = test_x_wavelet.values.reshape(len(test_x_wavelet), test_x_wavelet.shape[1], 1)

# %% [markdown]
# ## Building the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Flatten, Dropout, Softmax,BatchNormalization,Activation
from keras import regularizers

def ResidualBlock(model, inchannel, outchannel, stride=1):
    model.add(Conv1D(outchannel, kernel_size=3, strides=stride, padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Conv1D(outchannel, kernel_size=3, strides=1, padding='same', use_bias=False))
    model.add(BatchNormalization())

    if stride != 1 or inchannel != outchannel:
        model.add(Conv1D(outchannel, kernel_size=1, strides=stride, use_bias=False))
        model.add(BatchNormalization())

def ResNet18(input_shape=(380, 1), num_classes=5):
    model = Sequential()

    model.add(Conv1D(64, kernel_size=3, strides=1, padding='same', use_bias=False, input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    ResidualBlock(model, inchannel=64, outchannel=64, stride=1)
    ResidualBlock(model, inchannel=64, outchannel=128, stride=2)
    ResidualBlock(model, inchannel=128, outchannel=256, stride=2)
    ResidualBlock(model, inchannel=256, outchannel=512, stride=2)

    # Replace the AveragePooling1D layers with GlobalAveragePooling1D
    model.add(GlobalAveragePooling1D())

    model.add(Dense(35, kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))
    model.add(Softmax())

    return model

# Create ResNet18 model
model2 = ResNet18(input_shape=(380, 1))
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 380, 64)           192
#
#  batch_normalization (Batch  (None, 380, 64)           256
#  Normalization)
#
#  activation (Activation)     (None, 380, 64)           0
#
#  conv1d_1 (Conv1D)           (None, 380, 64)           12288
#
#  batch_normalization_1 (Bat  (None, 380, 64)           256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 380, 64)           0
#
#  conv1d_2 (Conv1D)           (None, 380, 64)           12288
#
#  batch_normalization_2 (Bat  (None, 380, 64)           256
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 190, 128)          24576
#
#  batch_normalization_3 (Bat  (None, 190, 128)          512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 190, 128)          0
#
#  conv1d_4 (Conv1D)           (None, 190, 128)          49152
#
#  batch_normalization_4 (Bat  (None, 190, 128)          512
#  chNormalization)
#
#  conv1d_5 (Conv1D)           (None, 95, 128)           16384
#
#  batch_normalization_5 (Bat  (None, 95, 128)           512
#  chNormalization)
#
#  conv1d_6 (Conv1D)           (None, 48, 256)           98304
#
#  batch_normalization_6 (Bat  (None, 48, 256)           1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 48, 256)           0
#
#  conv1d_7 (Conv1D)           (None, 48, 256)           196608
#
#  batch_normalization_7 (Bat  (None, 48, 256)           1024
#  chNormalization)
#
#  conv1d_8 (Conv1D)           (None, 24, 256)           65536
#
#  batch_normalization_8 (Bat  (None, 24, 256)           1024
#  chNormalization)
#
#  conv1d_9 (Conv1D)           (None, 12, 512)           393216
#
#  batch_normalization_9 (Bat  (None, 12, 512)           2048
#  chNormalization)
#
#  activation_4 (Activation)   (None, 12, 512)           0
#
#  conv1d_10 (Conv1D)          (None, 12, 512)           786432
#
#  batch_normalization_10 (Ba  (None, 12, 512)           2048
#  tchNormalization)
#
#  conv1d_11 (Conv1D)          (None, 6, 512)            262144
#
#  batch_normalization_11 (Ba  (None, 6, 512)            2048
#  tchNormalization)
#
#  global_average_pooling1d (  (None, 512)               0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 35)                17955
#
#  dense_1 (Dense)             (None, 5)                 180
#
#  softmax (Softmax)           (None, 5)                 0
#
# =================================================================
# Total params: 1946775 (7.43 MB)
# Trainable params: 1941015 (7.40 MB)
# Non-trainable params: 5760 (22.50 KB)
# _________________________________________________________________

# %% [markdown]
# ## Compiling the model

# %%
model2.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# ## Fitting the model

# %%
history2 = model2.fit(X_train_wavelet, train_y, batch_size=36, epochs=60, verbose=1, validation_data=(X_test_wavelet, test_y))
# Out:
# Epoch 1/60
# 556/556 [==============================] - 27s 25ms/step - loss: 0.3983 - accuracy: 0.8726 - val_loss: 0.7565 - val_accuracy: 0.8050
# Epoch 2/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.2423 - accuracy: 0.9218 - val_loss: 0.4533 - val_accuracy: 0.8602
# Epoch 3/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.1896 - accuracy: 0.9378 - val_loss: 0.2247 - val_accuracy: 0.9310
# Epoch 4/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.1629 - accuracy: 0.9467 - val_loss: 0.1335 - val_accuracy: 0.9588
# Epoch 5/60
# 556/556 [==============================] - 12s 21ms/step - loss: 0.1462 - accuracy: 0.9529 - val_loss: 0.1367 - val_accuracy: 0.9564
# Epoch 6/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.1228 - accuracy: 0.9614 - val_loss: 0.2662 - val_accuracy: 0.8978
# Epoch 7/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.1216 - accuracy: 0.9603 - val_loss: 0.2242 - val_accuracy: 0.9302
# Epoch 8/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.1104 - accuracy: 0.9629 - val_loss: 0.1176 - val_accuracy: 0.9630
# Epoch 9/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0949 - accuracy: 0.9694 - val_loss: 0.1745 - val_accuracy: 0.9498
# Epoch 10/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0911 - accuracy: 0.9708 - val_loss: 0.1316 - val_accuracy: 0.9578
# Epoch 11/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.0858 - accuracy: 0.9724 - val_loss: 0.1709 - val_accuracy: 0.9434
# Epoch 12/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0777 - accuracy: 0.9737 - val_loss: 0.1236 - val_accuracy: 0.9624
# Epoch 13/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0678 - accuracy: 0.9783 - val_loss: 0.1441 - val_accuracy: 0.9558
# Epoch 14/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0700 - accuracy: 0.9766 - val_loss: 0.1193 - val_accuracy: 0.9598
# Epoch 15/60
# 556/556 [==============================] - 10s 19ms/step - loss: 0.0644 - accuracy: 0.9783 - val_loss: 0.1044 - val_accuracy: 0.9682
# Epoch 16/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0601 - accuracy: 0.9797 - val_loss: 0.1037 - val_accuracy: 0.9656
# Epoch 17/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0545 - accuracy: 0.9816 - val_loss: 0.1252 - val_accuracy: 0.9602
# Epoch 18/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0479 - accuracy: 0.9838 - val_loss: 0.1072 - val_accuracy: 0.9670
# Epoch 19/60
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0513 - accuracy: 0.9822 - val_loss: 0.0941 - val_accuracy: 0.9716
# Epoch 20/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0470 - accuracy: 0.9837 - val_loss: 0.1124 - val_accuracy: 0.9662
# Epoch 21/60
# 556/556 [==============================] - 10s 19ms/step - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.1467 - val_accuracy: 0.9580
# Epoch 22/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.0870 - val_accuracy: 0.9734
# Epoch 23/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0383 - accuracy: 0.9872 - val_loss: 0.1206 - val_accuracy: 0.9676
# Epoch 24/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0408 - accuracy: 0.9861 - val_loss: 0.1168 - val_accuracy: 0.9712
# Epoch 25/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 0.0822 - val_accuracy: 0.9778
# Epoch 26/60
# 556/556 [==============================] - 10s 19ms/step - loss: 0.0382 - accuracy: 0.9873 - val_loss: 0.0665 - val_accuracy: 0.9828
# Epoch 27/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 0.1176 - val_accuracy: 0.9728
# Epoch 28/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0367 - accuracy: 0.9885 - val_loss: 0.0971 - val_accuracy: 0.9750
# Epoch 29/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0261 - accuracy: 0.9914 - val_loss: 0.0809 - val_accuracy: 0.9810
# Epoch 30/60
# 556/556 [==============================] - 10s 19ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.0623 - val_accuracy: 0.9834
# Epoch 31/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0254 - accuracy: 0.9915 - val_loss: 0.0843 - val_accuracy: 0.9792
# Epoch 32/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0248 - accuracy: 0.9922 - val_loss: 0.0740 - val_accuracy: 0.9810
# Epoch 33/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.1159 - val_accuracy: 0.9728
# Epoch 34/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.0886 - val_accuracy: 0.9776
# Epoch 35/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0229 - accuracy: 0.9936 - val_loss: 0.0659 - val_accuracy: 0.9832
# Epoch 36/60
# 556/556 [==============================] - 12s 21ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 0.0841 - val_accuracy: 0.9776
# Epoch 37/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0239 - accuracy: 0.9930 - val_loss: 0.0701 - val_accuracy: 0.9856
# Epoch 38/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0169 - accuracy: 0.9952 - val_loss: 0.1080 - val_accuracy: 0.9748
# Epoch 39/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0254 - accuracy: 0.9926 - val_loss: 0.0780 - val_accuracy: 0.9848
# Epoch 40/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.0888 - val_accuracy: 0.9796
# Epoch 41/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0140 - accuracy: 0.9966 - val_loss: 0.1138 - val_accuracy: 0.9744
# Epoch 42/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 0.0785 - val_accuracy: 0.9838
# Epoch 43/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.0725 - val_accuracy: 0.9872
# Epoch 44/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0203 - accuracy: 0.9941 - val_loss: 0.0944 - val_accuracy: 0.9790
# Epoch 45/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.0135 - accuracy: 0.9965 - val_loss: 0.0678 - val_accuracy: 0.9856
# Epoch 46/60
# 556/556 [==============================] - 10s 19ms/step - loss: 0.0209 - accuracy: 0.9940 - val_loss: 0.0654 - val_accuracy: 0.9842
# Epoch 47/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.0602 - val_accuracy: 0.9872
# Epoch 48/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.1349 - val_accuracy: 0.9680
# Epoch 49/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.0986 - val_accuracy: 0.9744
# Epoch 50/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.0683 - val_accuracy: 0.9844
# Epoch 51/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.1182 - val_accuracy: 0.9706
# Epoch 52/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0925 - val_accuracy: 0.9820
# Epoch 53/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.1057 - val_accuracy: 0.9824
# Epoch 54/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0138 - accuracy: 0.9962 - val_loss: 0.0871 - val_accuracy: 0.9854
# Epoch 55/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.0983 - val_accuracy: 0.9786
# Epoch 56/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0663 - val_accuracy: 0.9880
# Epoch 57/60
# 556/556 [==============================] - 10s 18ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.1331 - val_accuracy: 0.9684
# Epoch 58/60
# 556/556 [==============================] - 10s 19ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.0815 - val_accuracy: 0.9826
# Epoch 59/60
# 556/556 [==============================] - 11s 19ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.0740 - val_accuracy: 0.9854
# Epoch 60/60
# 556/556 [==============================] - 11s 20ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.0797 - val_accuracy: 0.9858

# %% [markdown]
# **Plotting the loss convergence**

# %%
# summarize history for loss
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Plotting accuracy**

# %%
# summarize history for accuracy
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Finding the loss and accuracy of the model

# %%
score = model2.evaluate(X_test_wavelet, test_y)

print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0797 - accuracy: 0.9858
# Test Loss: 0.0796889066696167
# Test accuracy: 0.98580002784729

# %%
model2.save('/content/drive/MyDrive/Colab Notebooks/PPTK/ResNet18/Parameters/ResNet18-bior6.8.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Assuming you have predictions from your model
predictions = model2.predict(X_test_wavelet)

# Convert predictions to one-hot encoding
y_pred = np.argmax(predictions, axis=1)

# Convert true labels to one-hot encoding
y_true = np.argmax(test_y, axis=1)

# Calculate confusion matrix
conf_mat = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_mat)

# Calculate precision, recall, and F1 score
report = classification_report(y_true, y_pred, target_names=classes)
print("Classification Report:")
print(report)
# Out:
# 157/157 [==============================] - 1s 3ms/step
# Confusion Matrix:
# [[1003    1    0   13    8]
#  [   5  961    0    0    4]
#  [   3    0  989    0    0]
#  [  22    1    1  962    0]
#  [   7    2    3    1 1014]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.96      0.98      0.97      1025
#            L       1.00      0.99      0.99       970
#            R       1.00      1.00      1.00       992
#            A       0.99      0.98      0.98       986
#            V       0.99      0.99      0.99      1027
#
#     accuracy                           0.99      5000
#    macro avg       0.99      0.99      0.99      5000
# weighted avg       0.99      0.99      0.99      5000

# %%
# Plot non-normalized confusion matrix
def plot_confusion_matrix(cm, classes,normalize=False,cmap="YlGnBu"):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    acc = "{:.2f}".format(np.trace(conf_mat)/np.sum(conf_mat)*100)
    plt.title('Confusion matrix \n Classification accuracy is: ' + str(acc)+'%')
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plt.figure(figsize=(5, 5))
plot_confusion_matrix(conf_mat, classes=classes,normalize=False)
plt.show()
